# %%
print("hello")
# Out:
# hello

# %%
2+2
# Out:
# 4

# %%
17/3
# Out:
# 5.666666666666667

# %%
17//3
# Out:
# 5

# %%
17%3
# Out:
# 2

# %%
5**2
# Out:
# 25

# %%
2**7
# Out:
# 128

# %%
4*3.75 -1
# Out:
# 14.0

# %%
word = 'Python'
word[0]
# Out:
# 'P'

# %%
word[0:2]
# Out:
# 'Py'

# %%
word[0:5]
# Out:
# 'Pytho'

# %%
x = int(input("Please enter an integer:"))
if x<0:
    x=0
    print('Negative changed to zero')
elif x ==0:
    print('Zero')
elif x==1:
    print('Single')
else:
    print("MOre")
# Out:
# Zero
